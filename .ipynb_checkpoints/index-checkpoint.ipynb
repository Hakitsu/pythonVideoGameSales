# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\quentin\appdata\local\programs\python\python310\lib\site-packages (1.5.3)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\quentin\appdata\local\programs\python\python310\lib\site-packages (from pandas) (1.24.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\quentin\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\quentin\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\quentin\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\quentin\appdata\local\programs\python\python310\lib\site-packages (3.7.1)
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\quentin\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\quentin\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\quentin\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (4.39.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\quentin\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in c:\users\quentin\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\quentin\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\quentin\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (23.0)
# Requirement already satisfied: numpy>=1.20 in c:\users\quentin\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.24.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\quentin\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\quentin\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
# !pip install fastapi
# Out:
# Requirement already satisfied: fastapi in c:\users\quentin\appdata\local\programs\python\python310\lib\site-packages (0.95.0)
# Requirement already satisfied: starlette<0.27.0,>=0.26.1 in c:\users\quentin\appdata\local\programs\python\python310\lib\site-packages (from fastapi) (0.26.1)
# Requirement already satisfied: pydantic!=1.7,!=1.7.1,!=1.7.2,!=1.7.3,!=1.8,!=1.8.1,<2.0.0,>=1.6.2 in c:\users\quentin\appdata\local\programs\python\python310\lib\site-packages (from fastapi) (1.10.7)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\quentin\appdata\local\programs\python\python310\lib\site-packages (from pydantic!=1.7,!=1.7.1,!=1.7.2,!=1.7.3,!=1.8,!=1.8.1,<2.0.0,>=1.6.2->fastapi) (4.5.0)
# Requirement already satisfied: anyio<5,>=3.4.0 in c:\users\quentin\appdata\local\programs\python\python310\lib\site-packages (from starlette<0.27.0,>=0.26.1->fastapi) (3.6.2)
# Requirement already satisfied: idna>=2.8 in c:\users\quentin\appdata\local\programs\python\python310\lib\site-packages (from anyio<5,>=3.4.0->starlette<0.27.0,>=0.26.1->fastapi) (3.4)
# Requirement already satisfied: sniffio>=1.1 in c:\users\quentin\appdata\local\programs\python\python310\lib\site-packages (from anyio<5,>=3.4.0->starlette<0.27.0,>=0.26.1->fastapi) (1.3.0)
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install xgboost
# Out:
# Requirement already satisfied: xgboost in c:\users\quentin\appdata\local\programs\python\python310\lib\site-packages (1.7.5)
# Requirement already satisfied: scipy in c:\users\quentin\appdata\local\programs\python\python310\lib\site-packages (from xgboost) (1.10.1)
# Requirement already satisfied: numpy in c:\users\quentin\appdata\local\programs\python\python310\lib\site-packages (from xgboost) (1.24.2)
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install -U scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\quentin\appdata\local\programs\python\python310\lib\site-packages (1.2.2)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\quentin\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn) (1.10.1)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\quentin\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\quentin\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn) (1.24.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\quentin\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn) (3.1.0)
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import matplotlib.pyplot as plt
from fastapi import FastAPI
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedKFold
from xgboost import XGBRegressor

# %%
app = FastAPI()

# %%
df = pd.read_csv("video_games_sales.csv")

# %%
df
# Out:
#         rank                                              name platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          year         genre   publisher  na_sales  eu_sales  jp_sales  \
# 0      2006.0        Sports    Nintendo     41.49     29.02      3.77
# 1      1985.0      Platform    Nintendo     29.08      3.58      6.81
# 2      2008.0        Racing    Nintendo     15.85     12.88      3.79
# 3      2009.0        Sports    Nintendo     15.75     11.01      3.28
# 4      1996.0  Role-Playing    Nintendo     11.27      8.89     10.22
# ...       ...           ...         ...       ...       ...       ...
# 16593  2002.0      Platform       Kemco      0.01      0.00      0.00
# 16594  2003.0       Shooter  Infogrames      0.01      0.00      0.00
# 16595  2008.0        Racing  Activision      0.00      0.00      0.00
# 16596  2010.0        Puzzle    7G//AMES      0.00      0.01      0.00
# 16597  2003.0      Platform     Wanadoo      0.01      0.00      0.00
#
#        other_sales  global_sales
# 0             8.46         82.74
# 1             0.77         40.24
# 2             3.31         35.82
# 3             2.96         33.00
# 4             1.00         31.37
# ...            ...           ...
# 16593         0.00          0.01
# 16594         0.00          0.01
# 16595         0.00          0.01
# 16596         0.00          0.01
# 16597         0.00          0.01
#
# [16598 rows x 11 columns]

# %% [markdown]
# transformé le name en valeur => (mot clé)
# Package -> word cloud (compter les fréquences de mot dans la liste)
# combien de genre / publisher / platform

# %%
df.describe()
# Out:
#                rank          year      na_sales      eu_sales      jp_sales  \
# count  16598.000000  16327.000000  16598.000000  16598.000000  16598.000000
# mean    8300.605254   2006.406443      0.264667      0.146652      0.077782
# std     4791.853933      5.828981      0.816683      0.505351      0.309291
# min        1.000000   1980.000000      0.000000      0.000000      0.000000
# 25%     4151.250000   2003.000000      0.000000      0.000000      0.000000
# 50%     8300.500000   2007.000000      0.080000      0.020000      0.000000
# 75%    12449.750000   2010.000000      0.240000      0.110000      0.040000
# max    16600.000000   2020.000000     41.490000     29.020000     10.220000
#
#         other_sales  global_sales
# count  16598.000000  16598.000000
# mean       0.048063      0.537441
# std        0.188588      1.555028
# min        0.000000      0.010000
# 25%        0.000000      0.060000
# 50%        0.010000      0.170000
# 75%        0.040000      0.470000
# max       10.570000     82.740000

# %%
# grouper par noms et calculer la moyenne des valeurs
df.groupby(["genre"]).agg({"eu_sales": "sum"}).reset_index()
# Out:
#            genre  eu_sales
# 0         Action    525.00
# 1      Adventure     64.13
# 2       Fighting    101.32
# 3           Misc    215.98
# 4       Platform    201.63
# 5         Puzzle     50.78
# 6         Racing    238.39
# 7   Role-Playing    188.06
# 8        Shooter    313.27
# 9     Simulation    113.38
# 10        Sports    376.85
# 11      Strategy     45.34

# %%
(df.groupby(["publisher"]).count().sort_values("rank", ascending=False)['rank']).nlargest(50)
# Out:
# publisher
# Electronic Arts                           1351
# Activision                                 975
# Namco Bandai Games                         932
# Ubisoft                                    921
# Konami Digital Entertainment               832
# THQ                                        715
# Nintendo                                   703
# Sony Computer Entertainment                683
# Sega                                       639
# Take-Two Interactive                       413
# Capcom                                     381
# Atari                                      363
# Tecmo Koei                                 338
# Square Enix                                233
# Warner Bros. Interactive Entertainment     232
# Disney Interactive Studios                 218
# Unknown                                    203
# Eidos Interactive                          198
# Midway Games                               198
# 505 Games                                  192
# Microsoft Game Studios                     189
# Acclaim Entertainment                      184
# D3Publisher                                184
# Vivendi Games                              164
# Codemasters                                152
# Idea Factory                               129
# Deep Silver                                122
# Nippon Ichi Software                       105
# Zoo Digital Publishing                     104
# Majesco Entertainment                       92
# LucasArts                                   90
# Rising Star Games                           86
# Hudson Soft                                 81
# Banpresto                                   73
# Bethesda Softworks                          71
# Crave Entertainment                         71
# Atlus                                       67
# Virgin Interactive                          62
# Infogrames                                  62
# Ignition Entertainment                      61
# 5pb                                         61
# Focus Home Interactive                      58
# Marvelous Interactive                       56
# Empire Interactive                          52
# SquareSoft                                  52
# Kadokawa Shoten                             50
# Destineer                                   45
# GT Interactive                              45
# DTP Entertainment                           45
# Alchemist                                   43
# Name: rank, dtype: int64

# %%
# grouper par année et genre et calculer les ventes totales
df_grouped = df.groupby(["year", "genre"])["eu_sales"].sum().reset_index()

# trouver l'index du genre le plus vendu pour chaque année
idx = df_grouped.groupby("year")["eu_sales"].idxmax()

# afficher le dataframe trié par année et le genre le plus vendu
print(df_grouped.loc[idx].sort_values("year"))
# Out:
#        year         genre  eu_sales
# 3    1980.0       Shooter      0.43
# 5    1981.0        Action      0.81
# 15   1982.0        Puzzle      0.58
# 22   1983.0      Platform      0.43
# 31   1984.0       Shooter      0.85
# 35   1985.0      Platform      3.77
# 40   1986.0        Action      1.66
# 48   1987.0      Fighting      0.65
# 54   1988.0      Platform      4.99
# 64   1989.0        Puzzle      3.61
# 69   1990.0      Platform      3.99
# 79   1991.0      Platform      1.19
# 88   1992.0     Adventure      2.81
# 103  1993.0      Platform      3.16
# 115  1994.0      Platform      5.73
# 127  1995.0      Platform      3.22
# 142  1996.0  Role-Playing     11.04
# 153  1997.0        Racing     10.82
# 159  1998.0        Action     11.90
# 178  1999.0  Role-Playing     11.17
# 183  2000.0        Action     10.84
# 195  2001.0        Action     19.25
# 207  2002.0        Action     27.01
# 219  2003.0        Action     20.88
# 238  2004.0  Role-Playing     16.73
# 243  2005.0        Action     21.95
# 265  2006.0        Sports     40.20
# 277  2007.0        Sports     26.54
# 279  2008.0        Action     39.49
# 301  2009.0        Sports     42.17
# 303  2010.0        Action     35.75
# 315  2011.0        Action     41.04
# 327  2012.0        Action     42.78
# 339  2013.0        Action     45.21
# 351  2014.0        Action     40.48
# 363  2015.0        Action     24.65
# 382  2016.0       Shooter      7.70
# 386  2017.0        Action      0.00
# 388  2020.0    Simulation      0.00

# %% [markdown]
# -------------------------------------
# # /!\ a supprimer /!\
#
# - Nettoyer la data
# - LabelEncoder
# - OneHotEncoder -> créer des categories (collones) -> a regarder
# - split train test
# - Xgboost Regression xgb(x.train, y.train) / xgb.predict(x.test, y.test)
#
# # /!\ a supprimer /!\
#
# -----------------------------------

# %%
df_filter = df.dropna()
df_filter
# Out:
#         rank                                              name platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          year         genre   publisher  na_sales  eu_sales  jp_sales  \
# 0      2006.0        Sports    Nintendo     41.49     29.02      3.77
# 1      1985.0      Platform    Nintendo     29.08      3.58      6.81
# 2      2008.0        Racing    Nintendo     15.85     12.88      3.79
# 3      2009.0        Sports    Nintendo     15.75     11.01      3.28
# 4      1996.0  Role-Playing    Nintendo     11.27      8.89     10.22
# ...       ...           ...         ...       ...       ...       ...
# 16593  2002.0      Platform       Kemco      0.01      0.00      0.00
# 16594  2003.0       Shooter  Infogrames      0.01      0.00      0.00
# 16595  2008.0        Racing  Activision      0.00      0.00      0.00
# 16596  2010.0        Puzzle    7G//AMES      0.00      0.01      0.00
# 16597  2003.0      Platform     Wanadoo      0.01      0.00      0.00
#
#        other_sales  global_sales
# 0             8.46         82.74
# 1             0.77         40.24
# 2             3.31         35.82
# 3             2.96         33.00
# 4             1.00         31.37
# ...            ...           ...
# 16593         0.00          0.01
# 16594         0.00          0.01
# 16595         0.00          0.01
# 16596         0.00          0.01
# 16597         0.00          0.01
#
# [16291 rows x 11 columns]

# %% [markdown]
# ##### recupérer les 50 éditeurs qui ont publié dans liste

# %%
df_publisher_no_unknown = df[df.publisher != 'Unknown']
df_publisher = (df_publisher_no_unknown.groupby(["publisher"]).count().sort_values("rank", ascending=False)['rank']).nlargest(50)
df_publisher
# Out:
# publisher
# Electronic Arts                           1351
# Activision                                 975
# Namco Bandai Games                         932
# Ubisoft                                    921
# Konami Digital Entertainment               832
# THQ                                        715
# Nintendo                                   703
# Sony Computer Entertainment                683
# Sega                                       639
# Take-Two Interactive                       413
# Capcom                                     381
# Atari                                      363
# Tecmo Koei                                 338
# Square Enix                                233
# Warner Bros. Interactive Entertainment     232
# Disney Interactive Studios                 218
# Midway Games                               198
# Eidos Interactive                          198
# 505 Games                                  192
# Microsoft Game Studios                     189
# Acclaim Entertainment                      184
# D3Publisher                                184
# Vivendi Games                              164
# Codemasters                                152
# Idea Factory                               129
# Deep Silver                                122
# Nippon Ichi Software                       105
# Zoo Digital Publishing                     104
# Majesco Entertainment                       92
# LucasArts                                   90
# Rising Star Games                           86
# Hudson Soft                                 81
# Banpresto                                   73
# Bethesda Softworks                          71
# Crave Entertainment                         71
# Atlus                                       67
# Virgin Interactive                          62
# Infogrames                                  62
# Ignition Entertainment                      61
# 5pb                                         61
# Focus Home Interactive                      58
# Marvelous Interactive                       56
# Empire Interactive                          52
# SquareSoft                                  52
# Kadokawa Shoten                             50
# DTP Entertainment                           45
# GT Interactive                              45
# Destineer                                   45
# Alchemist                                   43
# MTV Games                                   41
# Name: rank, dtype: int64

# %%
(df.groupby(["platform"]).count().sort_values("rank", ascending=False)['rank']).nlargest(50)
# Out:
# platform
# DS      2163
# PS2     2161
# PS3     1329
# Wii     1325
# X360    1265
# PSP     1213
# PS      1196
# PC       960
# XB       824
# GBA      822
# GC       556
# 3DS      509
# PSV      413
# PS4      336
# N64      319
# SNES     239
# XOne     213
# SAT      173
# WiiU     143
# 2600     133
# NES       98
# GB        98
# DC        52
# GEN       27
# NG        12
# SCD        6
# WS         6
# 3DO        3
# TG16       2
# PCFX       1
# GG         1
# Name: rank, dtype: int64

# %%
df_filter_not_unknown = df_filter[df_filter.publisher != 'Unknown']
df_filter_not_unknown
# Out:
#         rank                                              name platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          year         genre   publisher  na_sales  eu_sales  jp_sales  \
# 0      2006.0        Sports    Nintendo     41.49     29.02      3.77
# 1      1985.0      Platform    Nintendo     29.08      3.58      6.81
# 2      2008.0        Racing    Nintendo     15.85     12.88      3.79
# 3      2009.0        Sports    Nintendo     15.75     11.01      3.28
# 4      1996.0  Role-Playing    Nintendo     11.27      8.89     10.22
# ...       ...           ...         ...       ...       ...       ...
# 16593  2002.0      Platform       Kemco      0.01      0.00      0.00
# 16594  2003.0       Shooter  Infogrames      0.01      0.00      0.00
# 16595  2008.0        Racing  Activision      0.00      0.00      0.00
# 16596  2010.0        Puzzle    7G//AMES      0.00      0.01      0.00
# 16597  2003.0      Platform     Wanadoo      0.01      0.00      0.00
#
#        other_sales  global_sales
# 0             8.46         82.74
# 1             0.77         40.24
# 2             3.31         35.82
# 3             2.96         33.00
# 4             1.00         31.37
# ...            ...           ...
# 16593         0.00          0.01
# 16594         0.00          0.01
# 16595         0.00          0.01
# 16596         0.00          0.01
# 16597         0.00          0.01
#
# [16191 rows x 11 columns]

# %%
y_df = df_filter_not_unknown["eu_sales"]
y_df
# Out:
# 0        29.02
# 1         3.58
# 2        12.88
# 3        11.01
# 4         8.89
#          ...
# 16593     0.00
# 16594     0.00
# 16595     0.00
# 16596     0.01
# 16597     0.00
# Name: eu_sales, Length: 16191, dtype: float64

# %%
x_df = df_filter_not_unknown[["platform","year","genre","publisher","na_sales","jp_sales","global_sales"]]
x_df
# Out:
#       platform    year         genre   publisher  na_sales  jp_sales  \
# 0          Wii  2006.0        Sports    Nintendo     41.49      3.77
# 1          NES  1985.0      Platform    Nintendo     29.08      6.81
# 2          Wii  2008.0        Racing    Nintendo     15.85      3.79
# 3          Wii  2009.0        Sports    Nintendo     15.75      3.28
# 4           GB  1996.0  Role-Playing    Nintendo     11.27     10.22
# ...        ...     ...           ...         ...       ...       ...
# 16593      GBA  2002.0      Platform       Kemco      0.01      0.00
# 16594       GC  2003.0       Shooter  Infogrames      0.01      0.00
# 16595      PS2  2008.0        Racing  Activision      0.00      0.00
# 16596       DS  2010.0        Puzzle    7G//AMES      0.00      0.00
# 16597      GBA  2003.0      Platform     Wanadoo      0.01      0.00
#
#        global_sales
# 0             82.74
# 1             40.24
# 2             35.82
# 3             33.00
# 4             31.37
# ...             ...
# 16593          0.01
# 16594          0.01
# 16595          0.01
# 16596          0.01
# 16597          0.01
#
# [16191 rows x 7 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(x_df, y_df, test_size=0.3, random_state=123)

# %%
X_train
# Out:
#       platform    year         genre                     publisher  na_sales  \
# 7605       PS3  2010.0        Action  Konami Digital Entertainment      0.10
# 7817        DS  2010.0        Action                    Activision      0.17
# 3340        XB  2005.0      Fighting               Electronic Arts      0.42
# 16031      PSP  2009.0     Adventure                           TGL      0.00
# 4366       PS3  2008.0  Role-Playing                         Atari      0.19
# ...        ...     ...           ...                           ...       ...
# 12512      N64  1998.0        Sports                GT Interactive      0.05
# 1360      SNES  1994.0        Action                      Nintendo      0.57
# 11888      PS2  2004.0       Shooter                   Global Star      0.04
# 16107      PSV  2014.0     Adventure                  Idea Factory      0.00
# 3642       PS3  2009.0      Fighting                           THQ      0.30
#
#        jp_sales  global_sales
# 7605       0.04          0.20
# 7817       0.00          0.19
# 3340       0.00          0.60
# 16031      0.01          0.01
# 4366       0.07          0.45
# ...         ...           ...
# 12512      0.00          0.06
# 1360       0.71          1.42
# 11888      0.00          0.07
# 16107      0.01          0.01
# 3642       0.00          0.55
#
# [11333 rows x 7 columns]

# %%
y_test
# Out:
# 2959     0.09
# 1218     0.41
# 5092     0.00
# 11477    0.00
# 7921     0.08
#          ...
# 2805     0.16
# 9119     0.03
# 15654    0.01
# 9780     0.03
# 723      0.61
# Name: eu_sales, Length: 4858, dtype: float64

# %%
model = XGBRegressor()

# %%
cv = RepeatedKFold(n_splits=10, n_repeats=3, random_state=1)
# evaluate model
scores = cross_val_score(model, X_train, y_train, scoring='neg_mean_absolute_error', cv=cv, n_jobs=-1)
# force scores to be positive
scores = absolute(scores)
print('Mean MAE: %.3f (%.3f)' % (scores.mean(), scores.std()) )
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_scorer.py:430, in get_scorer(scoring)
#     429 try:
# --> 430     scorer = copy.deepcopy(_SCORERS[scoring])
#     431 except KeyError:
#
# KeyError: ''
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 3
#       1 cv = RepeatedKFold(n_splits=10, n_repeats=3, random_state=1)
#       2 # evaluate model
# ----> 3 scores = cross_val_score(model, X_train, y_train, scoring='', cv=cv, n_jobs='')
#       4 # force scores to be positive
#       5 scores = absolute(scores)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_validation.py:513, in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, error_score)
#     395 """Evaluate a score by cross-validation.
#     396
#     397 Read more in the :ref:`User Guide <cross_validation>`.
#    (...)
#     510 [0.3315057  0.08022103 0.03531816]
#     511 """
#     512 # To ensure multimetric format is not supported
# --> 513 scorer = check_scoring(estimator, scoring=scoring)
#     515 cv_results = cross_validate(
#     516     estimator=estimator,
#     517     X=X,
#    (...)
#     526     error_score=error_score,
#     527 )
#     528 return cv_results["test_score"]
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_scorer.py:479, in check_scoring(estimator, scoring, allow_none)
#     474     raise TypeError(
#     475         "estimator should be an estimator implementing 'fit' method, %r was passed"
#     476         % estimator
#     477     )
#     478 if isinstance(scoring, str):
# --> 479     return get_scorer(scoring)
#     480 elif callable(scoring):
#     481     # Heuristic to ensure user has not passed a metric
#     482     module = getattr(scoring, "__module__", None)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_scorer.py:432, in get_scorer(scoring)
#     430         scorer = copy.deepcopy(_SCORERS[scoring])
#     431     except KeyError:
# --> 432         raise ValueError(
#     433             "%r is not a valid scoring value. "
#     434             "Use sklearn.metrics.get_scorer_names() "
#     435             "to get valid options." % scoring
#     436         )
#     437 else:
#     438     scorer = scoring
#
# ValueError: '' is not a valid scoring value. Use sklearn.metrics.get_scorer_names() to get valid options.
